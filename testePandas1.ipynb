# %%
import pandas as pd

# %%
dados = pd.read_csv('/home/fifa.csv')
dados['total']=dados['Acceleration']+dados['Agility']
dados[['Name','Age','total']]

# %%
df=pd.read_csv('/home/house.csv')
df

# %%
filter1 = df.loc[(df['Rooms']==3)&(df['Type']=='h')&(df['Price']<=500000)]
filter1
